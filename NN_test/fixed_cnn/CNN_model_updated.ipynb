# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (9.4.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.22.4)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.0/993.0 kB 16.8 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.16 visualkeras-0.0.2

# %%
import numpy as np
import keras

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras import datasets
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization, LeakyReLU, Activation

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.models import load_model
from keras.layers import LeakyReLU

# %%
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

print('x_train shape:', x_train.shape)
print('y_train shape:', y_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step
# x_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 1)
# 50000 train samples
# 10000 test samples

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state = 42)

x_train.shape, x_val.shape, y_train.shape, y_val.shape
# Out:
# ((40000, 32, 32, 3), (10000, 32, 32, 3), (40000, 1), (10000, 1))

# %%
# Convert class vectors to binary class matrices. This is called one hot encoding.
num_classes = 10

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
print(y_train.shape, y_val.shape)
# Out:
# (40000, 10) (10000, 10)

# %%
# Normalize the data. Before we need to convert data type to float for computation.
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train /= 255
x_test /= 255

# %%
# @tf.keras.utils.register_keras_serializable(package="my_package", name="custom_leaky_relu")
def custom_leaky_relu(x):
    return LeakyReLU(0.1)(x)

model = Sequential()

# Block 1
model.add(Conv2D(32, (3, 3), padding='same', input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(Activation(custom_leaky_relu))
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation(custom_leaky_relu))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 2
model.add(Conv2D(128, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation(custom_leaky_relu))
model.add(Conv2D(256, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation(custom_leaky_relu))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Block 3
model.add(Conv2D(256, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation(custom_leaky_relu))
model.add(Conv2D(512, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation(custom_leaky_relu))

# Classification head
model.add(Flatten())
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation(custom_leaky_relu))
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation(custom_leaky_relu))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# Compile the model
opt = Adam(learning_rate=0.0001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 16, 16, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_3 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 16, 16, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  dropout (Dropout)           (None, 8, 8, 256)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_4 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 8, 8, 256)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  batch_normalization_5 (Batc  (None, 8, 8, 512)        2048
#  hNormalization)
#
#  activation_5 (Activation)   (None, 8, 8, 512)         0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 512)               16777728
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_6 (Activation)   (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_7 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_7 (Activation)   (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 19,078,346
# Trainable params: 19,074,314
# Non-trainable params: 4,032
# _________________________________________________________________

# %%
import visualkeras
from PIL import ImageFont

visualkeras.layered_view(model, legend=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=1631x207>

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1
)

history = model.fit(datagen.flow(x_train, y_train, batch_size=32),
                    epochs=100,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 1250/1250 [==============================] - 37s 21ms/step - loss: 1.7867 - accuracy: 0.3954 - val_loss: 1.7009 - val_accuracy: 0.4814
# Epoch 2/100
# 1250/1250 [==============================] - 27s 21ms/step - loss: 1.3536 - accuracy: 0.5275 - val_loss: 1.0923 - val_accuracy: 0.6307
# Epoch 3/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.1676 - accuracy: 0.5931 - val_loss: 1.2992 - val_accuracy: 0.5844
# Epoch 4/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 1.0536 - accuracy: 0.6316 - val_loss: 0.8172 - val_accuracy: 0.7131
# Epoch 5/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.9791 - accuracy: 0.6599 - val_loss: 0.9272 - val_accuracy: 0.6861
# Epoch 6/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.9119 - accuracy: 0.6819 - val_loss: 0.9174 - val_accuracy: 0.7045
# Epoch 7/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.8511 - accuracy: 0.7041 - val_loss: 0.7173 - val_accuracy: 0.7506
# Epoch 8/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.8105 - accuracy: 0.7205 - val_loss: 0.7537 - val_accuracy: 0.7434
# Epoch 9/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.7656 - accuracy: 0.7358 - val_loss: 0.6917 - val_accuracy: 0.7697
# Epoch 10/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.7332 - accuracy: 0.7469 - val_loss: 0.6537 - val_accuracy: 0.7769
# Epoch 11/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.6992 - accuracy: 0.7591 - val_loss: 0.6364 - val_accuracy: 0.7873
# Epoch 12/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.6771 - accuracy: 0.7668 - val_loss: 0.6760 - val_accuracy: 0.7705
# Epoch 13/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.6504 - accuracy: 0.7775 - val_loss: 0.6386 - val_accuracy: 0.7831
# Epoch 14/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.6228 - accuracy: 0.7854 - val_loss: 0.6803 - val_accuracy: 0.7743
# Epoch 15/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.6079 - accuracy: 0.7889 - val_loss: 0.5183 - val_accuracy: 0.8186
# Epoch 16/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.5910 - accuracy: 0.7997 - val_loss: 0.5971 - val_accuracy: 0.8047
# Epoch 17/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.5674 - accuracy: 0.8045 - val_loss: 0.6291 - val_accuracy: 0.7879
# Epoch 18/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.5544 - accuracy: 0.8111 - val_loss: 0.4789 - val_accuracy: 0.8354
# Epoch 19/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.5356 - accuracy: 0.8166 - val_loss: 0.4740 - val_accuracy: 0.8392
# Epoch 20/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.5197 - accuracy: 0.8220 - val_loss: 0.5006 - val_accuracy: 0.8282
# Epoch 21/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.5094 - accuracy: 0.8263 - val_loss: 0.5495 - val_accuracy: 0.8187
# Epoch 22/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.4936 - accuracy: 0.8314 - val_loss: 0.5002 - val_accuracy: 0.8289
# Epoch 23/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.4750 - accuracy: 0.8355 - val_loss: 0.4122 - val_accuracy: 0.8586
# Epoch 24/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.4708 - accuracy: 0.8396 - val_loss: 0.5072 - val_accuracy: 0.8306
# Epoch 25/100
# 1250/1250 [==============================] - 27s 21ms/step - loss: 0.4600 - accuracy: 0.8438 - val_loss: 0.5298 - val_accuracy: 0.8189
# Epoch 26/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.4447 - accuracy: 0.8480 - val_loss: 0.4515 - val_accuracy: 0.8508
# Epoch 27/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.4414 - accuracy: 0.8473 - val_loss: 0.5505 - val_accuracy: 0.8237
# Epoch 28/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.4319 - accuracy: 0.8534 - val_loss: 0.4260 - val_accuracy: 0.8553
# Epoch 29/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.4185 - accuracy: 0.8551 - val_loss: 0.4325 - val_accuracy: 0.8519
# Epoch 30/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.4163 - accuracy: 0.8557 - val_loss: 0.4465 - val_accuracy: 0.8506
# Epoch 31/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.4023 - accuracy: 0.8621 - val_loss: 0.3803 - val_accuracy: 0.8692
# Epoch 32/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3988 - accuracy: 0.8624 - val_loss: 0.4400 - val_accuracy: 0.8575
# Epoch 33/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3828 - accuracy: 0.8690 - val_loss: 0.4621 - val_accuracy: 0.8512
# Epoch 34/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3822 - accuracy: 0.8692 - val_loss: 0.4009 - val_accuracy: 0.8651
# Epoch 35/100
# 1250/1250 [==============================] - 27s 21ms/step - loss: 0.3676 - accuracy: 0.8744 - val_loss: 0.3450 - val_accuracy: 0.8814
# Epoch 36/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3626 - accuracy: 0.8758 - val_loss: 0.3780 - val_accuracy: 0.8736
# Epoch 37/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3573 - accuracy: 0.8779 - val_loss: 0.5087 - val_accuracy: 0.8397
# Epoch 38/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3492 - accuracy: 0.8796 - val_loss: 0.4014 - val_accuracy: 0.8691
# Epoch 39/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3475 - accuracy: 0.8798 - val_loss: 0.3664 - val_accuracy: 0.8759
# Epoch 40/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3342 - accuracy: 0.8854 - val_loss: 0.3733 - val_accuracy: 0.8747
# Epoch 41/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3365 - accuracy: 0.8850 - val_loss: 0.3808 - val_accuracy: 0.8713
# Epoch 42/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3252 - accuracy: 0.8884 - val_loss: 0.3946 - val_accuracy: 0.8669
# Epoch 43/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3195 - accuracy: 0.8892 - val_loss: 0.4392 - val_accuracy: 0.8563
# Epoch 44/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3130 - accuracy: 0.8925 - val_loss: 0.5069 - val_accuracy: 0.8373
# Epoch 45/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3092 - accuracy: 0.8931 - val_loss: 0.3831 - val_accuracy: 0.8730
# Epoch 46/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3024 - accuracy: 0.8963 - val_loss: 0.4237 - val_accuracy: 0.8557
# Epoch 47/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.3035 - accuracy: 0.8960 - val_loss: 0.3841 - val_accuracy: 0.8742
# Epoch 48/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2851 - accuracy: 0.9017 - val_loss: 0.3747 - val_accuracy: 0.8728
# Epoch 49/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2918 - accuracy: 0.8992 - val_loss: 0.3962 - val_accuracy: 0.8713
# Epoch 50/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2809 - accuracy: 0.9029 - val_loss: 0.3514 - val_accuracy: 0.8816
# Epoch 51/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2793 - accuracy: 0.9028 - val_loss: 0.4031 - val_accuracy: 0.8699
# Epoch 52/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2774 - accuracy: 0.9048 - val_loss: 0.3513 - val_accuracy: 0.8832
# Epoch 53/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2758 - accuracy: 0.9046 - val_loss: 0.3794 - val_accuracy: 0.8777
# Epoch 54/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2683 - accuracy: 0.9085 - val_loss: 0.3877 - val_accuracy: 0.8790
# Epoch 55/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2625 - accuracy: 0.9102 - val_loss: 0.3588 - val_accuracy: 0.8848
# Epoch 56/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2579 - accuracy: 0.9115 - val_loss: 0.3409 - val_accuracy: 0.8856
# Epoch 57/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2493 - accuracy: 0.9150 - val_loss: 0.3649 - val_accuracy: 0.8791
# Epoch 58/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2582 - accuracy: 0.9101 - val_loss: 0.3963 - val_accuracy: 0.8749
# Epoch 59/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2481 - accuracy: 0.9155 - val_loss: 0.3667 - val_accuracy: 0.8822
# Epoch 60/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2443 - accuracy: 0.9160 - val_loss: 0.3787 - val_accuracy: 0.8814
# Epoch 61/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2398 - accuracy: 0.9167 - val_loss: 0.4037 - val_accuracy: 0.8737
# Epoch 62/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2419 - accuracy: 0.9164 - val_loss: 0.3909 - val_accuracy: 0.8744
# Epoch 63/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2348 - accuracy: 0.9174 - val_loss: 0.3798 - val_accuracy: 0.8830
# Epoch 64/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2315 - accuracy: 0.9205 - val_loss: 0.3435 - val_accuracy: 0.8916
# Epoch 65/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2274 - accuracy: 0.9219 - val_loss: 0.3689 - val_accuracy: 0.8885
# Epoch 66/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2220 - accuracy: 0.9238 - val_loss: 0.3858 - val_accuracy: 0.8794
# Epoch 67/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2189 - accuracy: 0.9258 - val_loss: 0.3669 - val_accuracy: 0.8888
# Epoch 68/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2189 - accuracy: 0.9259 - val_loss: 0.3482 - val_accuracy: 0.8898
# Epoch 69/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2157 - accuracy: 0.9258 - val_loss: 0.3515 - val_accuracy: 0.8892
# Epoch 70/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2113 - accuracy: 0.9272 - val_loss: 0.3649 - val_accuracy: 0.8855
# Epoch 71/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2115 - accuracy: 0.9269 - val_loss: 0.4075 - val_accuracy: 0.8764
# Epoch 72/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2066 - accuracy: 0.9286 - val_loss: 0.3430 - val_accuracy: 0.8914
# Epoch 73/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2081 - accuracy: 0.9277 - val_loss: 0.3447 - val_accuracy: 0.8940
# Epoch 74/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.2027 - accuracy: 0.9309 - val_loss: 0.3561 - val_accuracy: 0.8911
# Epoch 75/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1960 - accuracy: 0.9317 - val_loss: 0.3200 - val_accuracy: 0.9004
# Epoch 76/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1946 - accuracy: 0.9328 - val_loss: 0.3609 - val_accuracy: 0.8929
# Epoch 77/100
# 1250/1250 [==============================] - 27s 21ms/step - loss: 0.1954 - accuracy: 0.9319 - val_loss: 0.3489 - val_accuracy: 0.8945
# Epoch 78/100
# 1250/1250 [==============================] - 27s 21ms/step - loss: 0.1902 - accuracy: 0.9339 - val_loss: 0.3315 - val_accuracy: 0.8974
# Epoch 79/100
# 1250/1250 [==============================] - 27s 21ms/step - loss: 0.1852 - accuracy: 0.9351 - val_loss: 0.3492 - val_accuracy: 0.8949
# Epoch 80/100
# 1250/1250 [==============================] - 27s 21ms/step - loss: 0.1903 - accuracy: 0.9352 - val_loss: 0.3651 - val_accuracy: 0.8897
# Epoch 81/100
# 1250/1250 [==============================] - 27s 22ms/step - loss: 0.1830 - accuracy: 0.9366 - val_loss: 0.4049 - val_accuracy: 0.8854
# Epoch 82/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1832 - accuracy: 0.9367 - val_loss: 0.3497 - val_accuracy: 0.8958
# Epoch 83/100
# 1250/1250 [==============================] - 27s 21ms/step - loss: 0.1841 - accuracy: 0.9343 - val_loss: 0.3289 - val_accuracy: 0.8988
# Epoch 84/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1773 - accuracy: 0.9378 - val_loss: 0.3472 - val_accuracy: 0.8951
# Epoch 85/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1756 - accuracy: 0.9390 - val_loss: 0.3638 - val_accuracy: 0.8928
# Epoch 86/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1763 - accuracy: 0.9382 - val_loss: 0.3512 - val_accuracy: 0.8955
# Epoch 87/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1735 - accuracy: 0.9399 - val_loss: 0.3470 - val_accuracy: 0.8934
# Epoch 88/100
# 1250/1250 [==============================] - 27s 21ms/step - loss: 0.1689 - accuracy: 0.9421 - val_loss: 0.3203 - val_accuracy: 0.9053
# Epoch 89/100
# 1250/1250 [==============================] - 27s 21ms/step - loss: 0.1702 - accuracy: 0.9414 - val_loss: 0.3836 - val_accuracy: 0.8894
# Epoch 90/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1668 - accuracy: 0.9413 - val_loss: 0.3936 - val_accuracy: 0.8834
# Epoch 91/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1652 - accuracy: 0.9425 - val_loss: 0.3780 - val_accuracy: 0.8914
# Epoch 92/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1603 - accuracy: 0.9445 - val_loss: 0.3537 - val_accuracy: 0.8955
# Epoch 93/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1592 - accuracy: 0.9455 - val_loss: 0.3984 - val_accuracy: 0.8873
# Epoch 94/100
# 1250/1250 [==============================] - 27s 21ms/step - loss: 0.1620 - accuracy: 0.9445 - val_loss: 0.3585 - val_accuracy: 0.8963
# Epoch 95/100
# 1250/1250 [==============================] - 27s 22ms/step - loss: 0.1536 - accuracy: 0.9462 - val_loss: 0.3031 - val_accuracy: 0.9078
# Epoch 96/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1546 - accuracy: 0.9470 - val_loss: 0.3732 - val_accuracy: 0.8918
# Epoch 97/100
# 1250/1250 [==============================] - 27s 21ms/step - loss: 0.1526 - accuracy: 0.9470 - val_loss: 0.3362 - val_accuracy: 0.9018
# Epoch 98/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1522 - accuracy: 0.9480 - val_loss: 0.3932 - val_accuracy: 0.8913
# Epoch 99/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1474 - accuracy: 0.9494 - val_loss: 0.3776 - val_accuracy: 0.8949
# Epoch 100/100
# 1250/1250 [==============================] - 26s 21ms/step - loss: 0.1477 - accuracy: 0.9485 - val_loss: 0.3552 - val_accuracy: 0.9010

# %%
test_eval = model.evaluate(x_test, y_test, verbose=2)

print('Test loss: {:.2f}%'.format(test_eval[0]))
print('Test accuracy:{:.2f}%'.format(test_eval[1]))
# Out:
# 313/313 - 2s - loss: 0.3552 - accuracy: 0.9010 - 2s/epoch - 5ms/step
# Test loss: 0.36%
# Test accuracy:0.90%

# %%
train_eval = model.evaluate(x_train, y_train, verbose=2)

print('Train loss:{:.2f}%'.format(train_eval[0]))
print('Train accuracy:{:.2f}%'.format(train_eval[1]))
# Out:
# 1250/1250 - 6s - loss: 0.0418 - accuracy: 0.9858 - 6s/epoch - 5ms/step
# Train loss:0.04%
# Train accuracy:0.99%

# %%
def plotmodelhistory(history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(history.history['accuracy'])
    axs[0].plot(history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['train', 'validate'], loc='upper left')
    # summarize history for loss
    axs[1].plot(history.history['loss'])
    axs[1].plot(history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['train', 'validate'], loc='upper left')
    plt.show()

# list all data in history
print(history.history.keys())

plotmodelhistory(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
def plothist(hist):
    plt.rcParams["figure.figsize"] = (16, 8)
    plt.plot(hist.history['accuracy'])
    plt.plot(hist.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.grid()
    plt.show()

# %%
plothist(history)

# %%
def plothist_loss(hist):
    plt.rcParams["figure.figsize"] = (16, 8)
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.grid()
    plt.show()

# %%
plothist_loss(history)

# %%
model.save('trained_model_updated.h5')

# %%
model.save_weights('trained_model_weights_updated.h5')

# %%
import pandas as pd

hist_df = pd.DataFrame(history.history)

# save to json:
hist_json_file = 'history_updated.json'
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# or save to csv:
hist_csv_file = 'history_updated.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
#  Model Architecture

# The model is a Sequential Model consisting of a total of 5 Convolutional Layers and 4 Dense Layers.

# The first Convolutional Layer starts with 32 filters and uses a kernel size of 2x2.
# Subsequent Convolutional Layers double the number of filters and increment the kernel size by 1 at each layer.
# To prevent overfitting and reduce computational costs, Max Pooling Layers are introduced after some of the Convolutional Layers.

# After the last Convolutional Layer, the output is flattened and passed to the Dense Layers.

# The first Dense Layer contains 512 neurons, and the number of neurons is halved over the next two Dense Layers.
# Throughout the model, Dropout Layers are added to randomly ignore some neurons during training and mitigate overfitting.

# ReLU activation is used in all layers except for the output layer. ReLU helps introduce non-linearity and reduces the computation cost.

# The Output Layer has 2 neurons, one for each class in the classification task, and uses softmax activation to provide probability scores for each class.

# Overall, the architecture is designed to extract relevant features through convolutional layers, reduce dimensions through pooling, and make the final classification decision through dense layers and softmax activation. Dropout layers are incorporated to enhance the model's generalization ability and prevent overfitting.
# Out:
# Mounted at /content/drive
